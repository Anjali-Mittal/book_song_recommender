# %%
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import CharacterTextSplitter
from langchain.embeddings import HuggingFaceEmbeddings
from langchain_chroma import Chroma
from langchain.docstore.document import Document

# %%
from dotenv import load_dotenv
load_dotenv()

# %%
import pandas as pd
books=pd.read_csv("books_cleaned.csv")

# %%
books["tagged_description"]

# %%
books["tagged_description"].to_csv("tagged_description.txt",
                                   sep="\n",
                                   header=False,
                                   index=False)

# %%
raw_documents=TextLoader("tagged_description.txt",encoding="utf-8").load()
text_splitter=CharacterTextSplitter(chunk_size=0,chunk_overlap=0,separator="\n")
#documents=text_splitter.split_documents(raw_documents)
from langchain.docstore.document import Document

# Build documents directly from your books DataFrame
documents = [
    Document(
        page_content=str(row["tagged_description"]),
        metadata={"isbn13": row["isbn13"], "title": row["title"]}
    )
    for _, row in books.iterrows()
]

# %%
documents[0]

# %%
import os
import sentence_transformers
import tf_keras as keras

# Loading env variables
model_name = os.getenv("EMBEDDING_MODEL")
chroma_dir = os.getenv("CHROMA_DB_DIR")

# Load the Hugging Face embedding model
embedding_model = HuggingFaceEmbeddings(model_name=model_name)

# Create Chroma vector DB
db_books = Chroma.from_documents(
    documents=documents,
    embedding=embedding_model,
    persist_directory=chroma_dir
)

# %%
print("Model name:", os.getenv("EMBEDDING_MODEL"))
print("Chroma dir:", os.getenv("CHROMA_DB_DIR"))
print(type(db_books))

# %%
def retrieve_semantic_recomendations(
        query:str,
        top_k: int=10,
)-> pd.DataFrame:
    recs=db_books.similarity_search(query,k=50)
    books_list=[]

    for i in range (0,len(recs)):
        books_list+=[int(recs[i].page_content.strip('"').split()[0])]
    
    return books[books["isbn13"].isin(books_list)].head(top_k)

# %%
def retrieve_semantic_recommendations(query: str, top_k: int = 10) -> pd.DataFrame:
    # Increase k to get more candidates for filtering
    recs = db_books.similarity_search(query, k=top_k * 20)
    
    # Collect ISBNs and titles for better matching
    isbn_list = []
    for rec in recs:
        if "isbn13" in rec.metadata:
            isbn_list.append(int(rec.metadata["isbn13"]))
    
    filtered_books = books[books["isbn13"].isin(isbn_list)]
    
    # Try to boost results that match the query in title or description
    query_lower = query.lower()
    def score_row(row):
        score = 0
        if query_lower in str(row["title"]).lower():
            score += 2
        if query_lower in str(row["description"]).lower():
            score += 1
        return score

    filtered_books = filtered_books.copy()
    filtered_books["score"] = filtered_books.apply(score_row, axis=1)
    filtered_books = filtered_books.sort_values(by=["score", "average_rating", "ratings_count"], ascending=[False, False, False])
    
    return filtered_books.drop(columns=["score"]).head(top_k)

# %%
def retrieve_semantic_recommendations(query: str, top_k: int = 10) -> pd.DataFrame:
    # Increase k to get more candidates for filtering
    recs = db_books.similarity_search(query, k=top_k * 20)
    
    # Collect ISBNs and titles for better matching
    isbn_list = []
    for rec in recs:
        if "isbn13" in rec.metadata:
            isbn_list.append(int(rec.metadata["isbn13"]))
    
    filtered_books = books[books["isbn13"].isin(isbn_list)]
    
    # Try to boost results that match the query in title or description
    query_lower = query.lower()
    def score_row(row):
        score = 0
        if query_lower in str(row["title"]).lower():
            score += 2
        if query_lower in str(row["description"]).lower():
            score += 1
        return score

    filtered_books = filtered_books.copy()
    filtered_books["score"] = filtered_books.apply(score_row, axis=1)
    filtered_books = filtered_books.sort_values(by=["score", "average_rating", "ratings_count"], ascending=[False, False, False])
    
    return filtered_books.drop(columns=["score"]).head(top_k)

# %%
retrieve_semantic_recommendations("a heartwarming journey of love and friendship")
# Out:
#              isbn13      isbn10                                   title  \
# 363   9780061120077  0061120073                A Tree Grows in Brooklyn
# 4841  9781590301876  1590301870                          Lovingkindness
# 4619  9781563893339  1563893339                                   Death
# 592   9780140195538  014019553X                             The Beloved
# 5023  9781852864989  1852864982                                   Death
# 383   9780061144899  0061144894                    When the Heart Waits
# 3846  9780804006941  0804006946                          A Woman Speaks
# 3     9780006280897  0006280897                          The Four Loves
# 4184  9780877887263  0877887268                 The Rock that is Higher
# 4434  9781401917173  1401917178  The Power of Infinite Love & Gratitude
#
#                                                 authors  \
# 363                                         Betty Smith
# 4841                     Sharon Salzberg;Jon Kabat-Zinn
# 4619  Neil Gaiman;Chris Bachalo;Mark Buckingham;Mike...
# 592                        Kahlil Gibran;John Walbridge
# 5023                                        Neil Gaiman
# 383                                       Sue Monk Kidd
# 3846                           Anaïs Nin;Evelyn J. Hinz
# 3                                   Clive Staples Lewis
# 4184                                  Madeleine L'Engle
# 4434                                 Darren R. Weissman
#
#                                  categories  \
# 363                                 Fiction
# 4841                              Self-Help
# 4619                Comics & Graphic Novels
# 592                                 Fiction
# 5023  Death (Fictitious character : Gaiman)
# 383                                Religion
# 3846                   Literary Collections
# 3                            Christian life
# 4184                               Religion
# 4434                       Health & Fitness
#
#                                               thumbnail  \
# 363   http://books.google.com/books/content?id=Y-FZ9...
# 4841  http://books.google.com/books/content?id=C9kY3...
# 4619  http://books.google.com/books/content?id=VIdbP...
# 592   http://books.google.com/books/content?id=KOEKA...
# 5023  http://books.google.com/books/content?id=5XnXO...
# 383   http://books.google.com/books/content?id=JlP91...
# 3846  http://books.google.com/books/content?id=-d5sP...
# 3     http://books.google.com/books/content?id=XhQ5X...
# 4184  http://books.google.com/books/content?id=Q-8EA...
# 4434  http://books.google.com/books/content?id=P6y0m...
#
#                                             description  published_year  \
# 363   The beloved American classic about a young gir...          2006.0
# 4841  In this inspiring book, Sharon Salzberg, one o...          2004.0
# 4619  A tale of music, mortality, friendship and dea...          1997.0
# 592   For Kahlil Gibran (1883-1931), love was the su...          1997.0
# 5023  A tale of music, mortality, friendship and dea...          1994.0
# 383   From the Bestselling Author of The Secret Life...          2006.0
# 3846  In this book Anais Nin speaks with warmth and ...          1975.0
# 3     Lewis' work on the nature of love divides love...          2002.0
# 4184  We are all strangers in a strange land, longin...          1993.0
# 4434  Would you like to discover your infinite poten...          2007.0
#
#       average_rating  num_pages  ratings_count  \
# 363             4.26      496.0       326733.0
# 4841            4.26      256.0         4072.0
# 4619            4.22       95.0        12206.0
# 592             4.19      102.0          320.0
# 5023            4.18      104.0        37678.0
# 383             4.17      240.0         2141.0
# 3846            4.16      288.0          184.0
# 3               4.15      170.0        33684.0
# 4184            4.13      320.0          457.0
# 4434            4.11      298.0           59.0
#
#                                      title_and_subtitle  \
# 363                            A Tree Grows in Brooklyn
# 4841  The Revolutionary Art of Happiness: Lovingkind...
# 4619                       The Time of Your Life: Death
# 592   Reflections on the Path of the Heart: The Beloved
# 5023                     The High Cost of Living: Death
# 383   Spiritual Direction for Life's Sacred Question...
# 3846  The Lectures, Seminars, and Interviews of Anai...
# 3                                        The Four Loves
# 4184            Story as Truth: The Rock that is Higher
# 4434  An Evolutionary Journey to Awakening Your Spir...
#
#                                      tagged_description
# 363   9780061120077 The beloved American classic abo...
# 4841  9781590301876 In this inspiring book, Sharon S...
# 4619  9781563893339 A tale of music, mortality, frie...
# 592   9780140195538 For Kahlil Gibran (1883-1931), l...
# 5023  9781852864989 A tale of music, mortality, frie...
# 383   9780061144899 From the Bestselling Author of T...
# 3846  9780804006941 In this book Anais Nin speaks wi...
# 3     9780006280897 Lewis' work on the nature of lov...
# 4184  9780877887263 We are all strangers in a strang...
# 4434  9781401917173 Would you like to discover your ...
